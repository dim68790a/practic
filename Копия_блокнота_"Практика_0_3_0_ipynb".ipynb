# %% [markdown]
# <a href="https://colab.research.google.com/github/dim68790a/practic/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_0_3_0_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ФИО

# %%
Горбук Дмитрий Михайлович
# Out:
# Привет

# %% [markdown]
# **Во всей практике нельзя применять библиотеки предоставляющие готовые решения!**

# %% [markdown]
# # **Задача 1.**

# %% [markdown]
# Типы данных Напишите программу на Python, которая принимает список чисел в качестве входных данных от пользователя, а затем выводит сумму, среднее значение и максимальное значение из списка.
#
# Дано:
# ```
# 1 2 3 4 5 6 7
# ```
# Вывод:
#
# ```
# Сумма чисел: 28
# Среднее арифм.: 4.0
# Максимальное значение: 7
# ```

# %%
x = str(input()).split()
z=0
q=0
y=0
for i in range(len(x)):
  y += int(x[z])
  if int(x[z])>q:
    q=int(x[z])
  z += 1
print("Сумма чисел:", y)
print("Среднее арифм. :", y/len(x))
print("Максимальное значение:",  q)
# Out:
# 1 2 3 4 5 6 7
# Сумма чисел: 28
# Среднее арифм. : 4.0
# Максимальное значение: 7

# %% [markdown]
# # **Задача 2.**

# %% [markdown]
# Напишите программу на Python, которая принимает список слов в качестве входных данных от пользователя, а затем распечатывает список в обратном порядке.
#
# Ввод:
#
# ```
# апельсин мандарин яблоко
# ```
#
# Вывод:
#
# ```
# яблоко мандарин апельсин
# ```

# %%
x = input().split()
z=1
y=""
for i in range(len(x)):
  y += x[len(x)-z]
  y += " "
  z+=1
print(y)
# Out:
# апельсин мандарин яблоко
# яблоко мандарин апельсин

# %% [markdown]
# # **Задача 3**

# %% [markdown]
# Простой чат-бот
# Создайте простого чат-бота, который отвечает на основные запросы пользователей. Программа должна использовать условные выражения для определения намерений пользователя и последующего соответствующего ответа.
#
# Чат бот может:
#
# - помогать складывать числа
# - подсказывать фильм, музыку и тд (из заранее созданного списка)
# - создавать список дел (а также выводить его, обновлять, очищать)
#
# Интерфейс чат-бота на ваше усмотрение, это могут быть как заранее определенные команды, так и к примеру вызов команды по номеру
#
# *Реализовать без использования функций*
#
# Пример:
#
# Ввод:
#
# ```
# Олег, какую мызыку посоветуешь?
# ```
#
# Вывод:
#
# ```
# Я бы посоветовал вам: Led Zeppelin Stairway to Heaven
# ```

# %%
y = 5
while y != 4:
 print("Что вас интересует? (Напишите цифру) 1. сложение чисел 2. подсказать фильм, музыку. 3. Создать список дел 4. Закончить")
 y = int(input())
 if y == 1:
  p=0
  z=0
  print("напишите все числа через пробел")
  x = str(input()).split()
  for i in range(len(x)):
    p += int(x[z])
    z+=1
  print(p)
 elif y == 2:
  x = str(input())
  z="Я бы посоветовал вам: "
  if "музыку" in x:
    z += "из музыки tytytyty"
  if "фильм" in x:
    z += "из фильмов пампампам"
  print(z)
 elif y == 3:
   y = 4
   z = list()
   while y!=3:
    print("Напишите цифру того что сделать 1. Добавить пункт 2. Убрать последний пункт. 3. Закончить")
    y = int(input())
    if y == 1:
      z.append(str(input()))
    if y == 2:
      z.pop()
   print(z)
# Out:
# Что вас интересует? (Напишите цифру) 1. сложение чисел 2. подсказать фильм, музыку. 3. Создать список дел 4. Закончить
# 1
# напишите все числа через пробел
# 22 333 44
# 399
# Что вас интересует? (Напишите цифру) 1. сложение чисел 2. подсказать фильм, музыку. 3. Создать список дел 4. Закончить
# 2
# Подскажи мне музыку и грустный фильм
# Я бы посоветовал вам: из музыки tytytytyиз фильмов пампампам
# Что вас интересует? (Напишите цифру) 1. сложение чисел 2. подсказать фильм, музыку. 3. Создать список дел 4. Закончить
# 3
# Напишите цифру того что сделать 1. Добавить пункт 2. Убрать последний пункт. 3. Закончить
# 1
# сделать дз
# Напишите цифру того что сделать 1. Добавить пункт 2. Убрать последний пункт. 3. Закончить
# 1
# сдать дз
# Напишите цифру того что сделать 1. Добавить пункт 2. Убрать последний пункт. 3. Закончить
# 2
# Напишите цифру того что сделать 1. Добавить пункт 2. Убрать последний пункт. 3. Закончить
# 3
# ['сделать дз']
# Что вас интересует? (Напишите цифру) 1. сложение чисел 2. подсказать фильм, музыку. 3. Создать список дел 4. Закончить
# 4

# %% [markdown]
# # **Задача 4.**

# %% [markdown]
# Камень, ножницы, бумага
#
# Создайте игру в Камень, ножницы, бумагу, в которой пользователь может играть против компьютера. Программа должна запросить выбор пользователя, а затем сгенерировать выбор компьютера. Затем программа должна определить победителя на основе правил игры.
#
# **Этап 1:**
#
# Определение победителя
#
# **Этап 2:**
#
# Игра до 3 побед
#
#
# Вввод для "Этап 1":
#
# ```
# Камень
# ```
#
# Вывод:
#
# ```
# Компьютер: Ножницы
# Игрок: Камень
# Победа: Игрок
# ```

# %%
import random
print("Играем до 3 побед")
z = 0
u = 0
while z != 3 and u != 3:
  x = random.randint(1, 3)
  print("что выкените вы напишите цифру(1.камень, 2.ножницы, 3.бумага)")
  y = int(input())
  if x == y:
    print("Ничья")
    continue
  if x ==1:
    if y == 3:
     z += 1
     print(f"PC выкинул камень вы бумагу игрок {z}, pc{u}")
    else:
     u += 1
     print(f"PC выкинул камень вы ножницы игрок {z}, pc{u}")
  if x ==2:
    if y == 1:
     z += 1
     print(f"PC выкинул ножницы вы камень игрок {z}, pc{u}")
    else:
     u += 1
     print(f"PC выкинул ножницы вы бумагу игрок {z}, pc{u}")
  if x ==3:
    if y == 2:
     z += 1
     print(f"PC выкинул бумага вы ножницы игрок {z}, pc{u}")
    else:
     u += 1
     print(f"PC выкинул бумага вы камень игрок {z}, pc{u}")
if z > u:
  print(f"Победил игрок со счетом игрок {z}, PC {u}")
else:
  print(f"Победил PC со счетом игрок {z}, PC {u}")
# Out:
# Играем до 3 побед
# что выкените вы напишите цифру(1.камень, 2.ножницы, 3.бумага)
# 2
# PC выкинул камень вы ножницы игрок 0, pc1
# что выкените вы напишите цифру(1.камень, 2.ножницы, 3.бумага)
# 3
# PC выкинул ножницы вы бумагу игрок 0, pc2
# что выкените вы напишите цифру(1.камень, 2.ножницы, 3.бумага)
# 1
# Ничья
# что выкените вы напишите цифру(1.камень, 2.ножницы, 3.бумага)
# 2
# PC выкинул камень вы ножницы игрок 0, pc3
# Победил PC со счетом игрок 0, PC 3

# %% [markdown]
# # **Задача 6.**

# %% [markdown]
# Создайте игру "Палач" или "Виселица", в которой пользователь должен угадать слово, предлагая буквы. Программа должна выбрать случайное слово, а затем разрешить пользователю угадывать буквы. После каждого угадывания программа должна сообщать пользователю, есть ли в слове буква или нет.
#
# **Этап 1**
# Создать саму игру
#
# **Этап 2:**
# Ввести подсчет количества очков и ограничения на попытки

# %%
import random
z = random.randint(0, 2)
x = ["снег", "дерево", "книга"]
y=x[z]
print(f"в слове {len(y)} букв у вас 7 жизней")
i = 7
t=0
while t != len(y) and i != 0:
  print("Предложи букву")
  r = str(input())
  if r in y:
    t += y.count(r)
    print(f"Да эта буква есть их {y.count(r)} в слове")
  else:
    i -= 1
    print(f"вы не угадали минус жизнь у вас {i}")
if i > 0:
  print(f"Вы победили это было слово {x[z]}")
else:
  print(f"Вы проиграли это было слово {x[z]}")
# Out:
# в слове 5 букв у вас 7 жизней
# Предложи букву
# а
# Да эта буква есть их 1 в слове
# Предложи букву
# к
# Да эта буква есть их 1 в слове
# Предложи букву
# н
# Да эта буква есть их 1 в слове
# Предложи букву
# и
# Да эта буква есть их 1 в слове
# Предложи букву
# г
# Да эта буква есть их 1 в слове
# Вы победили это было слово книга

# %% [markdown]
# # **Задача 7.**

# %% [markdown]
# **Цифра на определенном месте:**
#
# Последовательно записан натуральный ряд чисел.
#
# Какая цифра стоит в N позиции
#
#
# Вввод:
#
# ```
# Введите номер позиции: 1234567890
# ```
#
# Вывод:
#
# ```
# 8
# ```

# %%
x = str(input())
x.replace(" ", "")
print("позиция:")
y = int(input())
print(x[y-1])
# Out:
# 1234567890
# позиция:
# 8
# 8
